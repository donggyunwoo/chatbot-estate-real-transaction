# %%
import requests
import json

# %%
url = 'http://apis.data.go.kr/1611000/nsdi/BuildingUseService/attr/getBuildingUse'
key = 'cUrXjCod9NLhb2dpkxgVyG0Yc0KPGFKFDGyfN5StAQ2qJQVBDM7g0e64CxRoYXW5hYfKu5muWtCVSxeY0p3kCg=='
params ={'serviceKey' : f'{key}', 'pageNo' : '1', 'numOfRows' : '10', 'pnu' : '11740107001', 'mainPrposCode' : '02000', 'detailPrposCode' : '02001', 'format' : 'json' }

response = requests.get(url, params=params)
response.json()
# Out:
# {'buildingUses': {'field': [{'regstrSeCode': '1',
#     'pnu': '1174010700104000000',
#     'mnnmSlno': '400',
#     'regstrSeCodeNm': '일반',
#     'lastUpdtDt': '2022-02-23',
#     'buldNm': '강동 현대홈타운',
#     'buldDongNm': '109동',
#     'ldCode': '1174010700',
#     'ldCodeNm': '서울특별시 강동구 암사동',
#     'buldIdntfcNo': '2217',
#     'agbldgSeCode': '2',
#     'agbldgSeCodeNm': '집합건축물',
#     'buldKndCode': '3',
#     'buldKndCodeNm': '표제부',
#     'buldTotar': '3195.92',
#     'strctCode': '21',
#     'strctCodeNm': '철근콘크리트구조',
#     'mainPrposCode': '02000',
#     'mainPrposCodeNm': '공동주택',
#     'gisIdntfcNo': '2004212259004505182700000000',
#     'buldMainAtachSeCode': '0',
#     'buldMainAtachSeCodeNm': '주건축물',
#     'buldPlotAr': '0',
#     'buldBildngAr': '201.03',
#     'measrmtRt': '0',
#     'btlRt': '0',
#     'detailPrposCode': '02001',
#     'detailPrposCodeNm': '아파트',
#     'buldPrposClCode': '1',
#     'buldPrposClCodeNm': '주거용',
#     'buldHg': '52.4',
# ...
